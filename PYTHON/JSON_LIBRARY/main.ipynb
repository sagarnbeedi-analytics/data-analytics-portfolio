# %% [markdown]
# ### START

# %% [markdown]
# ### JSON PYTHON LIBRARY
# - json library is important for data analyst since the API responses are iften collected in json format
# - configuration files are also the json files
# - json can either consists of list or dictionary in it
# - json is used for semi struture data storage
# - json files is also used in logging and automation pipelines

# %% [markdown]
# ### JSON AND PYTHON DATA TYPES
# - json object is python dictionary
# - json array is python list
# - json string is python str
# - json number is python int/float
# - json boolean is python bool
# - json null is ython none
