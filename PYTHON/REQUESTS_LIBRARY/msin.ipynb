# %% [markdown]
# ### START

# %% [markdown]
# ### REQUESTS PYTHON LIBRARY
# - as a data analyst requests is the data ingestion tool
# - previously the flow was like csv--excel-- analysis
# - now its API-- python--pandas-- excel/Database-- dashboards

# %% [markdown]
# IMPORTING THE REQUESTS PYTHON LIBRARY

# %%
import requests
